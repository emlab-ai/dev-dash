# %%
# !pip3 install requests
# Out:
# 145.39s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (2024.8.30)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3.13 -m pip install --upgrade pip

# %%
import requests

# Set the context and prompt
context = "Your context here"
prompt = "Your prompt here"

# Define the API endpoint and your API key
api_endpoint = "https://api.gemini.com/v1/your_endpoint"
api_key = "your_api_key"

# Create the headers for the request
headers = {
    "Content-Type": "application/json",
    "X-GEMINI-APIKEY": api_key
}

# Create the payload for the request
payload = {
    "context": context,
    "prompt": prompt
}

# Make the API call
response = requests.post(api_endpoint, headers=headers, json=payload)

# Read the reply
reply = response.json()
print(reply)
# Out:
# {'result': 'error', 'reason': 'EndpointNotFound', 'message': 'API entry point `/v1/your_endpoint` not found'}

# %%
# !pip3 install vertexai
# Out:
# 152.94s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: vertexai in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.71.1)
# Requirement already satisfied: google-cloud-aiplatform==1.71.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-aiplatform[all]==1.71.1->vertexai) (1.71.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.23.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.36.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (5.28.3)
# Requirement already satisfied: packaging>=14.3 in /Users/alex.malafeev/Library/Python/3.13/lib/python/site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (24.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.18.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (3.27.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.13.1)
# Requirement already satisfied: shapely<3.0.0dev in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.0.6)
# Requirement already satisfied: pydantic<3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.9.2)
# Requirement already satisfied: docstring-parser<1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (0.16)
# WARNING: google-cloud-aiplatform 1.71.1 does not provide the extra 'all'
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.67.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.67.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.3 in /Users/alex.malafeev/Library/Python/3.13/lib/python/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic<3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (4.12.2)
# Requirement already satisfied: numpy<3,>=1.14 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from shapely<3.0.0dev->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.1.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (0.6.1)
# Requirement already satisfied: six>=1.5 in /Users/alex.malafeev/Library/Python/3.13/lib/python/site-packages (from python-dateutil<3.0dev,>=2.7.3->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai) (2024.8.30)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3.13 -m pip install --upgrade pip

# %%
import vertexai
from vertexai.generative_models import GenerativeModel

# TODO(developer): Update and un-comment below line
PROJECT_ID = "firefly-dev-2018"
vertexai.init(project=PROJECT_ID, location="us-central1")

model = GenerativeModel("gemini-1.5-flash-002")

response = model.generate_content(
    "What's a good name for a flower shop that specializes in selling bouquets of dried flowers?"
)

print(response.text)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# **Evocative & Romantic:**
#
# * Everlasting Blooms
# * The Dried Petal
# * Whispers of Bloom
# * Timeless Blooms
# * Bloom & Preserve
# * Dried & Delightful
# * Botanical Echoes
# * The Everlasting Garden
# * Sun-Kissed Blooms
# * Autumn Hues Floral
#
# **Modern & Chic:**
#
# * The Bloom Archive
# * Petal & Stem
# * Dried & Styled
# * Flora & Fade
# * Botanical Legacy
# * The Lasting Bouquet
# * Hues of Yesterday
# * Preserve & Bloom
#
# **Unique & Playful:**
#
# * The Paper Petal
# * Forever in Bloom
# * Bloom Room
# * The Dried Bouquet Bar
# * The Petal Press
#
#
# When choosing, consider:
#
# * **Your target audience:**  A more modern name might appeal to a younger demographic, while a romantic name might suit a more traditional clientele.
# * **Your brand aesthetic:**  Does your shop have a rustic, minimalist, or luxurious feel?  The name should reflect this.
# * **Memorability:**  A short, catchy name is easier to remember and recommend.
# * **Availability:** Check if the name is available as a website domain and social media handle.
#
#
# Good luck with your flower shop!

# %%
import vertexai
from vertexai.generative_models import GenerativeModel
from vertexai import caching

# TODO(developer): Update and un-comment below line
PROJECT_ID = "firefly-dev-2018"
vertexai.init(project=PROJECT_ID, location="us-central1")

model = GenerativeModel("gemini-1.5-flash-002")

# Create a cache with a 5 minute TTL
cache = caching.CachedContent.create(
    model='models/gemini-1.5-flash-002',
    display_name='sherlock jr movie', # used to identify the cache
    system_instruction=(
        'You are an expert video analyzer, and your job is to answer '
        'the user\'s query based on the video file you have access to.'
    ),
    contents=[video_file],
    ttl=datetime.timedelta(minutes=5),
)

response = model.generate_content(
    "What's a good name for a flower shop that specializes in selling bouquets of dried flowers?"
)

print(response.text)
# Out:
# **Elegant & Sophisticated:**
#
# * Everlasting Blooms
# * The Dried Petal
# * Bloom & Preserve
# * Timeless Blossoms
# * Whispering Meadows
# * The Botanical Archive
# * The Dried Flower Atelier
# * Eternal Flora
# * Amber & Ash (evokes color and preservation)
#
# **Rustic & Charming:**
#
# * The Dried Bouquet
# * Sun-Kissed Stems
# * Meadow & Vine
# * The Wildflower Post
# * Gather & Grace
# * Rustic Blooms
# * Hayloft Flowers
#
# **Modern & Minimalist:**
#
# * Bloom Dry
# * Everlasting
# * Petal & Stem
# * Dried & Co.
# * Flora Preserved
#
#
# **Unique & Creative:**
#
# * The Paper Petal (if using preserved paper flowers)
# * Stardust Blooms (if focusing on shimmery/glittery dried flowers)
# * Botanical Legacy
# * The Memory Garden
# * Whispers of Autumn (if specializing in autumnal colors)
#
#
# When choosing, consider your target audience and the overall aesthetic you want to project.  Good luck!

# %%
# !pip3 install sqlalchemy sqlalchemy.orm psycopg2
# Out:
# 105844.82s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: sqlalchemy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.0.36)
# Requirement already satisfied: sqlalchemy.orm in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.2.10)
# Collecting psycopg2
#   Downloading psycopg2-2.9.10.tar.gz (385 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: inflection in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sqlalchemy.orm) (0.5.1)
# Requirement already satisfied: cached-property in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sqlalchemy.orm) (2.0.1)
# Requirement already satisfied: typing-inspect in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sqlalchemy.orm) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from typing-inspect->sqlalchemy.orm) (1.0.0)
# Building wheels for collected packages: psycopg2
#   Building wheel for psycopg2 (pyproject.toml) ... done
#   Created wheel for psycopg2: filename=psycopg2-2.9.10-cp313-cp313-macosx_10_13_universal2.whl size=243473 sha256=66969e4e331ff37c38fc96a61f1c73a6f21f3dbbb7f448eb237a90ef67d93144
#   Stored in directory: /Users/alex.malafeev/Library/Caches/pip/wheels/d1/02/6b/6fab072a7ac365814e6d6217fef5525fa5ac3c64204a418040
# Successfully built psycopg2
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.10
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3.13 -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker

# Define the database URL
db_url = 'postgresql://emlabserver:3CeuOw_1WLS#>NO$t<86}TebqFnw@emlab.cfugkypxw81e.eu-west-2.rds.amazonaws.com:5432/EmlabDatabase'

# Create an engine
engine = create_engine(db_url)

# Create a configured "Session" class
Session = sessionmaker(bind=engine)

# Create a Session
session = Session()

# Define the table name
user_name = 'lcrab-dojo'

# Perform the query
result = session.execute(text(f'SELECT * FROM public.pull_requests where author=\'{user_name}\' limit 20 '))
rows = result.fetchall()
# Get column names
columns = result.keys()
column_indices = {column: index for index, column in enumerate(columns)}

# Iterate over the results and print in the specified format
prompt=''
for row in rows:
    output = {
        'Title': row[column_indices['title']],
        'RepoId': row[column_indices['repository_id']],
        'Description': row[column_indices['body']],
        'URL': row[column_indices['url']]
    }
    prompt += str(output) + ',\n'

print(prompt)

# Close the session
session.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 if not fairy:
# -> 1263     fairy = _ConnectionRecord.checkout(pool)
#    1265     if threadconns is not None:
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/engine/create.py:643, in create_engine.<locals>.connect(connection_record)
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/engine/default.py:621, in DefaultDialect.connect(self, *cargs, **cparams)
#     619 def connect(self, *cargs, **cparams):
#     620     # inherits the docstring from interfaces.Dialect.connect
# --> 621     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: connection to server at "emlab.cfugkypxw81e.eu-west-2.rds.amazonaws.com" (18.171.131.198), port 5432 failed: FATAL:  password authentication failed for user "emlabserver"
# connection to server at "emlab.cfugkypxw81e.eu-west-2.rds.amazonaws.com" (18.171.131.198), port 5432 failed: FATAL:  no pg_hba.conf entry for host "195.224.145.249", user "emlabserver", database "EmlabDatabase", no encryption
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 21
#      18 user_name = 'lcrab-dojo'
#      20 # Perform the query
# ---> 21 result = session.execute(text(f'SELECT * FROM public.pull_requests where author=\'{user_name}\' limit 20 '))
#      22 rows = result.fetchall()
#      23 # Get column names
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/orm/session.py:2362, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2301 def execute(
#    2302     self,
#    2303     statement: Executable,
#    (...)
#    2309     _add_event: Optional[Any] = None,
#    2310 ) -> Result[Any]:
#    2311     r"""Execute a SQL expression construct.
#    2312
#    2313     Returns a :class:`_engine.Result` object representing
#    (...)
#    2360
#    2361     """
# -> 2362     return self._execute_internal(
#    2363         statement,
#    2364         params,
#    2365         execution_options=execution_options,
#    2366         bind_arguments=bind_arguments,
#    2367         _parent_execute_state=_parent_execute_state,
#    2368         _add_event=_add_event,
#    2369     )
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/orm/session.py:2237, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2223     (
#    2224         statement,
#    2225         execution_options,
#    (...)
#    2232         False,
#    2233     )
#    2235 bind = self.get_bind(**bind_arguments)
# -> 2237 conn = self._connection_for_bind(bind)
#    2239 if _scalar_result and not compile_state_cls:
#    2240     if TYPE_CHECKING:
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/orm/session.py:2106, in Session._connection_for_bind(self, engine, execution_options, **kw)
#    2104 if trans is None:
#    2105     trans = self._autobegin_t()
# -> 2106 return trans._connection_for_bind(engine, execution_options)
#
# File <string>:2, in _connection_for_bind(self, bind, execution_options)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/orm/state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     137 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#     141     raise
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/orm/session.py:1189, in SessionTransaction._connection_for_bind(self, bind, execution_options)
#    1184             raise sa_exc.InvalidRequestError(
#    1185                 "Session already has a Connection associated "
#    1186                 "for the given Connection's Engine"
#    1187             )
#    1188     else:
# -> 1189         conn = bind.connect()
#    1190         local_connect = True
#    1192 try:
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3278, in Engine.connect(self)
#    3255 def connect(self) -> Connection:
#    3256     """Return a new :class:`_engine.Connection` object.
#    3257
#    3258     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3275
#    3276     """
# -> 3278     return self._connection_cls(self)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/engine/base.py:148, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
# --> 148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#     151         raise
#     152 else:
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2442, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2440 elif should_wrap:
#    2441     assert sqlalchemy_exception is not None
# -> 2442     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2443 else:
#    2444     assert exc_info[1] is not None
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3302, in Engine.raw_connection(self)
#    3280 def raw_connection(self) -> PoolProxiedConnection:
#    3281     """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283     The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301     """
# -> 3302     return self.pool.connect()
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/engine/create.py:643, in create_engine.<locals>.connect(connection_record)
#     640         if connection is not None:
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/sqlalchemy/engine/default.py:621, in DefaultDialect.connect(self, *cargs, **cparams)
#     619 def connect(self, *cargs, **cparams):
#     620     # inherits the docstring from interfaces.Dialect.connect
# --> 621     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/.pyenv/versions/3.13.0/lib/python3.13/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "emlab.cfugkypxw81e.eu-west-2.rds.amazonaws.com" (18.171.131.198), port 5432 failed: FATAL:  password authentication failed for user "emlabserver"
# connection to server at "emlab.cfugkypxw81e.eu-west-2.rds.amazonaws.com" (18.171.131.198), port 5432 failed: FATAL:  no pg_hba.conf entry for host "195.224.145.249", user "emlabserver", database "EmlabDatabase", no encryption
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import vertexai
from vertexai.generative_models import GenerativeModel
from google.oauth2 import service_account
import json

keyFile = '/Users/alex.malafeev/Downloads/firefly-dev-2018-8ae87f2c1d5f.json'

# Read the JSON key file
with open(keyFile, 'r') as file:
    key_info = json.load(file)

# Create credentials for GCP service account from JSON key info
credentials = service_account.Credentials.from_service_account_info(key_info)


# TODO(developer): Update and un-comment below line
PROJECT_ID = "firefly-dev-2018"
vertexai.init(credentials=credentials)



system_prompt = """
<OBJECTIVE_AND_PERSONA>
You are a team lead, and need to write a report of what your team member has producted.
You are receiveing list of documents, containing: Title, RepoId, Description, URL.
Some of the descriptions contain ticket ids, which are in the format of 'TICKET-1234'. Example: CPP-1233 or HS-089
</OBJECTIVE_AND_PERSONA>

<INSTRUCTIONS>
To complete the task, you need to follow these steps:
1. Group changes by RepoId.
2. Extract all ticket ids from the descriptions.
3. Execute a query to get the ticket details for each ticket id.
4. Read titile and description of each ticket, and summarize the work done.
5. When summarizing focus on the change (PR) but not on the repository, be very specific, and use only data from the PR description, dont' made any assumptions.
6. If ticket has no valid number, write <invalid ticket>, example: CPP-xx, xx is not number.
7. Add quality score (from 1 to 10), use the same criteria as in the summary section.
</INSTRUCTIONS>

<OUTPUT_FORMAT>
Description: Summary of the work done, explain what was done, why it was done.
Repository:[RepoId1, RepoId2, RepoId3], // (only group repositories if the change relates to the same promlem solved)
Tickets: [TICKET-1234, TICKET-1235]

make sure output is machine readable, write it in JSON format.
Schema example:
{
    Work: [
    {
        "Description": "Summary of the work done, explain what was done, why it was done.",
        "Repository": ["RepoId1, RepoId2, RepoId3"],
        "Tickets": ["TICKET-1234", "TICKET-1235"],
        "Quality score": 7
    }],
    Summary: "summary text",
    AvgQuality: 4
}

</OUTPUT_FORMAT>

<SUMMARY>
Summary quality of work done by the team member, how good PRs are, is it clear enought what was done, does all PRs have tickets, etc.
Do not include any judgements not based on the data provided.
Criteria:
- each PR has a ticket
- each PR description explain the problem
- each PR description explain the solution
- each PR description explain how it was tested
</SUMMARY>

"""
model = GenerativeModel(model_name="gemini-1.5-flash-002", system_instruction=system_prompt)

response = model.generate_content(
    prompt
)

# Access token usage from the response metadata
try:
    tokens_used = response.usage_metadata.total_token_count
    print(f"Tokens used: {tokens_used}")
except AttributeError:
    print("Token usage information not available in the response metadata.")


print(response.text)
# Out:
# Tokens used: 5988
# ```json
# {
#   "Work": [
#     {
#       "Description": "Modified the apps handler to process product names and adjusted the model to transmit only necessary partner information instead of the entire class.",
#       "Repository": [808605738],
#       "Tickets": ["pppp 1193"],
#       "Quality score": 7
#     },
#     {
#       "Description": "Resolved a bug causing setup intents to expire prematurely by adding the `refreshClientSessionSecret` field. This field, when set to true (automatically by the checkout page), refreshes the token only if it has expired. The logic mirrors that of payment intents. The PR also renames `document` to `setupIntentDocument` for clarity and updates the test API version.",
#       "Repository": [411223918],
#       "Tickets": ["pppp 1204"],
#       "Quality score": 9
#     },
#     {
#       "Description": "<invalid ticket>",
#       "Repository": [808605738],
#       "Tickets": [],
#       "Quality score": 1
#     },
#     {
#       "Description": "Reformatted the partner search page and partner details page to align with the redesign.",
#       "Repository": [472667608],
#       "Tickets": ["pppp 1207"],
#       "Quality score": 8
#     },
#     {
#       "Description": "Implemented a partner details page that retrieves partner information based on a selected ID.  New endpoints were added to Partners, and error handling was implemented for invalid or non-existent partner IDs.",
#       "Repository": [472667608],
#       "Tickets": ["pppp 1187"],
#       "Quality score": 9
#     },
#     {
#       "Description": "Added new integration tests for the partner service.",
#       "Repository": [808605738],
#       "Tickets": ["pppp 1044"],
#       "Quality score": 7
#     },
#     {
#       "Description": "Renamed the location integration to \"activate product\" with a two-line text change.  A visual change is shown in the bottom right button.",
#       "Repository": [472667608],
#       "Tickets": ["pppp-1200"],
#       "Quality score": 6
#     },
#     {
#       "Description": "Added reseller functionality to the partner details page, addressing layout issues.  This involved creating separate tabs based on partner type, implementing logic for app integrations, creating a custom partner details class, and updating padding and layout to match the Figma design.",
#       "Repository": [472667608],
#       "Tickets": ["pppp 1195"],
#       "Quality score": 9
#     },
#     {
#       "Description": "Implemented the \"add product\" button functionality, enabling users to create new products, define their names and permissions, add them to the database, and update the table. New endpoints and models were created.",
#       "Repository": [472667608],
#       "Tickets": ["pppp 1193"],
#       "Quality score": 9
#     },
#     {
#       "Description": "Renamed AddApps to GetApps.",
#       "Repository": [808605738],
#       "Tickets": [],
#       "Quality score": 5
#     },
#     {
#       "Description": "<invalid ticket>",
#       "Repository": [467175725],
#       "Tickets": ["1370"],
#       "Quality score": 1
#     },
#     {
#       "Description": "Updated typographies to match Aga's designs.  The only change to the rest of RP Admin is that table headers are now bold and buttons are slightly larger.",
#       "Repository": [472667608],
#       "Tickets": ["pppp 1232"],
#       "Quality score": 8
#     },
#     {
#       "Description": "Removed logic for the next button, preventing it from proceeding to the next dialog without additional checks.",
#       "Repository": [472667608],
#       "Tickets": ["pppp 1237"],
#       "Quality score": 7
#     },
#     {
#       "Description": "Added a check to ensure no product within a partner's products shares the same name as the requested name, along with a test for this functionality.",
#       "Repository": [808605738],
#       "Tickets": [],
#       "Quality score": 8
#     },
#     {
#       "Description": "Added a check for unique partner names.",
#       "Repository": [472667608],
#       "Tickets": [],
#       "Quality score": 7
#     },
#     {
#       "Description": "Removed a `$` symbol from a string in the payment link field.",
#       "Repository": [411223918],
#       "Tickets": ["1002"],
#       "Quality score": 6
#     },
#     {
#       "Description": "<invalid ticket>",
#       "Repository": [411223918],
#       "Tickets": [],
#       "Quality score": 1
#     },
#     {
#       "Description": "<invalid ticket>",
#       "Repository": [411223918],
#       "Tickets": [],
#       "Quality score": 1
#     },
#     {
#       "Description": "Added a restriction to `UpdateAccessTokenAsync` to maintain consistent logic, now checking within `UpdateAccessToken` whether the payment intent is F2F Only or if remote payments are disabled.",
#       "Repository": [411223918],
#       "Tickets": ["1566"],
#       "Quality score": 8
#     },
#     {
#       "Description": "Changed the default partner user status to active by modifying the enum.",
#       "Repository": [808605738],
#       "Tickets": [],
#       "Quality score": 6
#     }
#   ],
#   "Summary": "The team member delivered a mixed bag of PRs.  Several PRs were well-documented, clearly explaining the problem, solution, and testing procedures (e.g., pppp 1204, pppp 1187, pppp 1195). However, some PRs lacked sufficient detail (e.g., several with invalid or missing tickets, and some with incomplete descriptions).  There's a clear need for improvement in consistently providing complete information for all PRs, including thorough testing procedures and valid ticket numbers.",
#   "AvgQuality": 6
# }
# ```
