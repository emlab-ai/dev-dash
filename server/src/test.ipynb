# %%
import base64
import jwt
import requests
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.primitives.asymmetric import rsa
import json

token = 'eyJ0eXAiOiJKV1QiLCJub25jZSI6ImpNWGhLN29HUVhrNFpZTXlXaW52SXZQTFFxcktfX0RKM2xTeHZ3LS1BaGMiLCJhbGciOiJSUzI1NiIsIng1dCI6IlhSdmtvOFA3QTNVYVdTblU3Yk05blQwTWpoQSIsImtpZCI6IlhSdmtvOFA3QTNVYVdTblU3Yk05blQwTWpoQSJ9.....nUdELJ0yilI13yjXe1CUwP5Nxhtum_fnm-4RDI7HpsONzesUhWa_XKX4BEfqvees93q5r2opGWwLCZHN6AB1gYULlWUikXf--TCSWsRHiqJCULg2ru-GMqRD88KKbgvSQFU_Jht3zJMGf-mtaT4Xg55BbH3i-7r6QeOscE0ywryhuloLRoyeW6pY3W3y3yYDG2w__AIa00ksGjY93KeStI47eIhOhYi6tmVQplD640zGKmDtJG5rhM4MgsKOZ_tZ8oWQcBrzongnCZwNSoOM9Y8u9Kmqqwij5-bmsrZnlMHaVmpIn2n9XVXOj2f0UtUNzKyKZajGUgZStn23B3yn_w'

# Function to retrieve the public key for token validation
def get_public_key(token):
    # Make a request to the OpenID configuration endpoint
    response = requests.get('https://login.microsoftonline.com/common/.well-known/openid-configuration')
    if response.status_code == 200:
        # Extract the jwks_uri from the response
        jwks_uri = response.json()['jwks_uri']
        # Make a request to the jwks_uri to retrieve the public keys
        response = requests.get(jwks_uri)
        if response.status_code == 200:
            # Extract the public keys from the response
            public_keys = response.json()['keys']
            # Find the matching public key based on the token's kid (key ID)
            for key in public_keys:
                if key['kid'] == jwt.get_unverified_header(token)['kid']:
                    return key
    return None

def base64url_to_int(base64url_string):
    # Base64url decode the string
    padding = '=' * (4 - (len(base64url_string) % 4))
    base64url_string += padding
    decoded_string = base64.urlsafe_b64decode(base64url_string)
    # Convert the decoded bytes to an integer
    return int.from_bytes(decoded_string, 'big')

# Function to validate the bearer token
def validate_bearer_token(token):
    # Retrieve the public key for token validation
    public_key = get_public_key(token)

    # Extract the necessary components from the dictionary
    n = base64url_to_int(public_key['n'])
    e = base64url_to_int(public_key['e'])

    # Create a public key object
    public_key_obj = rsa.RSAPublicNumbers(e, n).public_key()

    # Serialize the public key to PEM format
    public_key_pem = public_key_obj.public_bytes(
        encoding=serialization.Encoding.PEM,
        format=serialization.PublicFormat.SubjectPublicKeyInfo
    )

    # Print the PEM-formatted public key
    public_key = public_key_pem.decode()
    
    
    if public_key:
        try:
            # Decode and verify the token using the public key
            decoded_token = jwt.decode(token, public_key, algorithms=['RS256'])
            return decoded_token
        except jwt.ExpiredSignatureError:
            print('Token has expired.')
        except jwt.InvalidTokenError as e:
            print('Invalid token.' + str(e))
    else:
        print('Failed to retrieve public key for token validation.')
    return None

# Validate the bearer token
decoded_token = validate_bearer_token(token)
if decoded_token:
    print('Token is valid.')
    # You can access the claims in the decoded token using decoded_token['claim_name']
else:
    print('Token is invalid.')
# Out:
# Invalid token.Signature verification failed
# Token is invalid.

# %%
from flask import Flask, request, jsonify
from jose import jwt
from jose.exceptions import JWTError
import requests
token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IlhSdmtvOFA3QTNVYVdTblU3Yk05blQwTWpoQSIsImtpZCI6IlhSdmtvOFA3QTNVYVdTblU3Yk05blQwTWpoQSJ9.....GbggtSts_D2jn0kQKaAqRyMrYuIv5_Savlqz4J_sZmR8ivbF39u9HMSBJEuA5ZsaUCaqURmBQ7zOgM4uhq3xcDNw80nhfbxTNhaiLj2jShxez46UlnPaSqAtWHdvUfNuCXSQzXf-ktB6Ttjdlh0xUcwkdTa8Mszu9PNr2bPTp4djSlSP6qKEVaPAafvdKVVVBkTE27JISk_s3mMfaNiDMkj_DLO_JpYxIETwo-8oUZiWYDQroXXI9t0BZpfW9eu6ehkpqrk9RDYY00duxN68GYo0DXE-Sf3-4u6nGem0YoUD_iJb_VIyEGoEJ3M7btsi70LkRrTvVbfvW2VDDKefOg'

def get_signing_keys(jwks_uri):
    response = requests.get(jwks_uri)
    jwks = response.json()
    return {key["kid"]: key for key in jwks["keys"]}


jwks_uri = 'https://login.microsoftonline.com/common/discovery/keys'
signing_keys = get_signing_keys(jwks_uri)
header = jwt.get_unverified_header(token)
key = signing_keys[header["kid"]]

# Decode the token
decoded_token = jwt.decode(token, key, algorithms=['RS256'], audience='api://aa990489-4089-45e6-b48b-00f4510c9147')

decoded_token

# %%
import jwt
import time
from cryptography.hazmat.backends import default_backend
from cryptography.hazmat.primitives import serialization

# Your GitHub App's identifier
app_id = '861923'

# Load the private key
with open('/Users/alex.malafeev/Projects/emlab-ai.2024-03-25.private-key.pem', 'rb') as key_file:
    private_key = serialization.load_pem_private_key(
        key_file.read(),
        password=None,
        backend=default_backend()
    )

# Generate the JWT
time_now = int(time.time())
payload = {
    # issued at time
    'iat': time_now,
    # JWT expiration time (10 minute maximum)
    'exp': time_now + (10 * 60),
    # GitHub App's identifier
    'iss': app_id
}

token = jwt.encode(
    payload,
    private_key,
    algorithm='RS256'
)

print(token)
# Out:
# eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE3MTE0NzcxNTcsImV4cCI6MTcxMTQ3Nzc1NywiaXNzIjoiODYxOTIzIn0.OtoJSQzB1e4dNQRR_wVOM-55P2AERzY_x50nhH1fBs8UsM3YvkL81oX_SiLLq857y4XvSl-SbowWElKq0nCN6NlkQtrFynKCuFZ-zcqmmf-SZGHN8g8qepPK3-8vBxs-9rCzEizzbsIaswaXvhH3ZuN3gr8STiTkKGq_npliTBcDrWa_z2788mELcIpPJGmYyytyz4KHyeI2p5yFdtgvpJzgJuR33-Zxt6YPX3SRo1S2AN8v9l2riVR_AYp6uc_PHMu_vyt-_D57Ssda3-_D1i0SoZXuUCylBPwKzqmPo_CJsjllgbOGaCSU9weHrkSXux-HVsCzw2wNcw3r1FaWIQ

# %%
import requests

# Replace `installation_id` with your GitHub App's installation ID
installation_id = '48861059'

headers = {
    'Authorization': f'Bearer {token}',
    'Accept': 'application/vnd.github+json'
}

response = requests.post(
    f'https://api.github.com/app/installations/{installation_id}/access_tokens',
    headers=headers
)

access_token = response.json()['token']

# %%
access_token
# Out:
# 'ghs_5AEPQKPOIljc8ZhJfZPBjpphem7UE72Db9ah'

# %%
query = """
query {
  viewer {
    repositories(first: 100, affiliations: [OWNER, COLLABORATOR, ORGANIZATION_MEMBER]) {
      totalCount
      edges {
        node {
          name
          owner {
            login
          }
          isPrivate
          createdAt
          url
          description
        }
      }
      pageInfo {
        endCursor
        hasNextPage
      }
    }
  }
}


"""

headers = {
    'Authorization': f'token {access_token}',
    'Accept': 'application/vnd.github+json'
}

response = requests.post(
    'https://api.github.com/graphql',
    json={'query': query},
    headers=headers
)

print(response.json())
# Out:
# {'data': {'viewer': {'repositories': {'totalCount': 2, 'edges': [{'node': {'name': 'dev-dash', 'owner': {'login': 'emlab-ai'}, 'isPrivate': True, 'createdAt': '2024-03-10T21:00:43Z', 'url': 'https://github.com/emlab-ai/dev-dash', 'description': None}}, {'node': {'name': 'test-repo', 'owner': {'login': 'emlab-ai'}, 'isPrivate': True, 'createdAt': '2024-03-25T11:42:58Z', 'url': 'https://github.com/emlab-ai/test-repo', 'description': None}}], 'pageInfo': {'endCursor': 'Y3Vyc29yOnYyOpHOLlMDgw==', 'hasNextPage': False}}}}}
